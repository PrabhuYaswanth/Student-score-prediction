# %%
print("Hello prabhu")
# Out:
# Hello prabhu

# %%
import pandas as pd

# %%
# Load Data

# %%
df = pd.read_csv("students.csv")

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df
# Out:
#    Student ID  Hours_Studied  Marks
# 0           1              1     20
# 1           2              2     35
# 2           3              3     50
# 3           4              4     65
# 4           5              5     80
# 5           6              6     90
# 6           7              7     95

# %%
df.sort_values(by="Marks",ascending=False)
# Out:
#    Student ID  Hours_Studied  Marks
# 6           7              7     95
# 5           6              6     90
# 4           5              5     80
# 3           4              4     65
# 2           3              3     50
# 1           2              2     35
# 0           1              1     20

# %%
# For data visualization Math Plot libarary

# %%
import matplotlib.pyplot as plt

# %%
#  graph plot data can access particular data (eg) df['Hours_Studied'] -> x-axis

# %%
plt.scatter(df['Hours_Studied'],df['Marks'])
plt.title("Hours vs Marks")
plt.xlabel("Hours Studied")
plt.ylabel("Marks Scored")
plt.show()

# %%
# Test and Train, takes the data for train & testing,model_selection -> path

# %%
from sklearn.model_selection import train_test_split

# %%
# storing the data before trainning and testing,-> inputs are features,more inputs can be given in future represent it in 2D

# %%
X = df[['Hours_Studied']]

# %%
# more inputs are give, we get single output

# %%
Y = df['Marks']

# %%
# train & test individual X,Y test size 20% random state it takes repeated data does not changes data

# %%
#X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2,random_state=42) for Lrge data

# %%
#train the program ,Linear REGRESSION is model

# %%
from sklearn.linear_model import LinearRegression

# %%
# function call

# %%
model = LinearRegression()

# %%
# fit -> collects the training data

# %%
model.fit(X,Y)
# Out:
# LinearRegression()

# %%
predicted = model.predict(X_test)

# %%
# zip to combine to data

# %%
for hours , mark in zip(X['Hours_Studied'],predicted):
    print(f"Hours Studied : {hours} -> Marks Scored: {mark} ")
# Out:
# Hours Studied : 1 -> Marks Scored: 30.0
# Hours Studied : 2 -> Marks Scored: 41.5
